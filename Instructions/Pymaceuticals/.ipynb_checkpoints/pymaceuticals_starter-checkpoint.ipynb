# %% [markdown]
# ## Observations and Insights

# %%
# Observations about the data below:
    
#     1. The drug regimen are evenly spread with an almost equal number of mice in each sample group.
#     2. The Capomulin successfully lowere the tumor volume in s185 over the course of the regimen.
#     3. The mouse weight and tumor size are closely correlated in the Capomulin group.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import linregress

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
combined_data_df = pd.merge(mouse_metadata, study_results, how='outer', on='Mouse ID')

combined_data_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice.
number_of_mice = combined_data_df["Mouse ID"].nunique()
number_of_mice
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
duplicate_mouse_id = combined_data_df[combined_data_df.duplicated(["Mouse ID", "Timepoint"])]
duplicate_mouse_id
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 909     g989     Propriva  Female          21          26          0
# 911     g989     Propriva  Female          21          26          5
# 913     g989     Propriva  Female          21          26         10
# 915     g989     Propriva  Female          21          26         15
# 917     g989     Propriva  Female          21          26         20
#
#      Tumor Volume (mm3)  Metastatic Sites
# 909           45.000000                 0
# 911           47.570392                 0
# 913           49.880528                 0
# 915           53.442020                 0
# 917           54.657650                 1

# %%
# Optional: Get all the data for the duplicate mouse ID. 
duplicate_mouse_id_all = combined_data_df[combined_data_df.duplicated(["Mouse ID", "Timepoint"], keep=False)]
duplicate_mouse_id_all
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 908     g989     Propriva  Female          21          26          0
# 909     g989     Propriva  Female          21          26          0
# 910     g989     Propriva  Female          21          26          5
# 911     g989     Propriva  Female          21          26          5
# 912     g989     Propriva  Female          21          26         10
# 913     g989     Propriva  Female          21          26         10
# 914     g989     Propriva  Female          21          26         15
# 915     g989     Propriva  Female          21          26         15
# 916     g989     Propriva  Female          21          26         20
# 917     g989     Propriva  Female          21          26         20
#
#      Tumor Volume (mm3)  Metastatic Sites
# 908           45.000000                 0
# 909           45.000000                 0
# 910           48.786801                 0
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
 
mouse_df  = combined_data_df[ combined_data_df['Mouse ID'] == "g989" ].index
  
combined_data_df.drop(mouse_df, inplace = True)

combined_data_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice in the clean DataFrame.
num_mice = combined_data_df["Mouse ID"].nunique()
num_mice
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
drug_group_data = combined_data_df.groupby(["Drug Regimen"])

drug_group_mean = drug_group_data.mean()
drug_group_median = drug_group_data.median()
drug_group_var = drug_group_data.var()
drug_group_std = drug_group_data.std()
drug_group_sem = drug_group_data.sem()


# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary dataframe.

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
drug_group_mean
drug_group_median
drug_group_var
drug_group_std 
drug_group_sem
# Using the aggregation method, produce the same summary statistics in a single line
drug_group_data.agg(['mean', 'median', 'var', 'std', 'sem'])
# Out:
#              Age_months                                       Weight (g)  \
#                    mean median        var       std       sem       mean
# Drug Regimen
# Capomulin     13.456522   16.5  59.620372  7.721423  0.509136  19.965217
# Ceftamin      13.247191   12.0  65.147591  8.071406  0.604977  27.398876
# Infubinol     16.230337   20.0  56.404272  7.510278  0.562919  27.196629
# Ketapril      15.659574   18.0  36.236432  6.019670  0.439030  27.861702
# Naftisol      12.000000    9.0  45.102703  6.715855  0.492430  27.166667
# Placebo       10.734807   10.0  40.384837  6.354907  0.472356  27.928177
# Propriva      10.006757    7.5  48.251655  6.946341  0.570986  27.135135
# Ramicane      10.684211    9.0  35.362393  5.946629  0.393825  19.679825
# Stelasyn      12.784530   14.0  63.036648  7.939562  0.590143  27.856354
# Zoniferol     12.598901   12.5  33.479115  5.786114  0.428895  27.692308
#
#                                                     ... Tumor Volume (mm3)  \
# ...

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of unique mice tested on each drug regimen using pandas.

grouped_mice_data = combined_data_df.groupby("Drug Regimen")
grouped_mice_data = grouped_mice_data.agg({"Mouse ID":"nunique"})
grouped_mice_data = grouped_mice_data.reset_index()

mice_regimen_data = grouped_mice_data.set_index("Drug Regimen")

mice_regimen_data.plot(kind="bar", figsize=(10,10), color='b', alpha = .75, align="center")
plt.title("Number of Mice Per Drug Regimen")
plt.xlabel("Drug Regimen ")
plt.ylabel("Number of Mice")
plt.ylim(0,30)
plt.show()
plt.tight_layout()

# %%
# Generate a bar plot showing the total number of unique mice tested on each drug regimen using pyplot.
mice = mice_regimen_data["Mouse ID"]
x_axis = np.arange(len(mice_regimen_data))

tick_locations = [value for value in x_axis]
plt.xticks(tick_locations,["Capomulin", "Ceftamin", "Infubinol","Ketapril","Naftisol","Placebo","Propriva","Ramicane","Stelasyn","Zoniferol"], rotation="vertical")

plt.bar(x_axis, mice, color='b', alpha = .75, align="center")
plt.title("Number of Mice Per Drug Regimen")
plt.xlabel("Drug Regimen")
plt.ylabel("Number of Mice")
plt.ylim(0,30)
plt.show()
plt.tight_layout()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas

combined_data_df["Sex"].value_counts().plot(kind='pie', colors = ["green", "orange"], autopct="%1.1f%%") 
plt.title("Sex of Mice")
combined_data_df["Sex"].value_counts()
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot

# Generate a pie plot showing the distribution of female versus male mice using pandas
# Labels for the sections of our pie chart
labels = ["Male", "Female"]

# The values of each section of the pie chart
number = [958, 922]

# The colors of each section of the pie chart
colors = ["green", "orange"]

# Tells matplotlib to seperate the "Humans" section from the others
explode = (0, 0)

plt.pie(number, explode=explode, labels=labels, colors=colors, autopct="%1.1f%%",
       shadow=True,)

plt.title("Sex of Mice")
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse


# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
final_tumor_value_df = combined_data_df.drop_duplicates(subset="Mouse ID", keep='last')

tumor_value_df = final_tumor_value_df[(final_tumor_value_df['Drug Regimen'] == "Capomulin")|(final_tumor_value_df['Drug Regimen'] == "Ramicane")| (final_tumor_value_df['Drug Regimen'] == "Infubinol")|(final_tumor_value_df['Drug Regimen'] == "Ceftamin")]
tumor_value_df
# Out:
#      Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 9        k403     Ramicane    Male          21          16         45
# 19       s185    Capomulin  Female           3          17         45
# 29       x401    Capomulin  Female          16          15         45
# 39       m601    Capomulin    Male          22          17         45
# 49       g791     Ramicane    Male          11          16         45
# ...       ...          ...     ...         ...         ...        ...
# 1797     x822     Ceftamin    Male           3          29         45
# 1813     y163    Infubinol  Female          17          27         45
# 1845     y769     Ceftamin  Female           6          27         45
# 1855     y865     Ceftamin    Male          23          26         45
# 1872     z581    Infubinol  Female          24          25         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 9              22.050126                 1
# ...

# %%
# Put treatments into a list for for loop (and later for plot labels)

treatments = ["capomulin", "ramicane", "infubinol", "ceftamin"]


# Create empty list to fill with tumor vol data (for plotting)

tumor_value = tumor_value_df[ 'Tumor Volume (mm3)']

# Calculate the IQR and quantitatively determine if there are any potential outliers. 
quartiles = tumor_value.quantile([.25,.5,.75])
lowerq = quartiles[0.25]
upperq = quartiles[0.75]
iqr = upperq-lowerq
    
    # Locate the rows which contain mice on each drug and get the tumor volumes
    
    
    # add subset 
    
    
    # Determine outliers using upper and lower bounds
lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
tumor_value = tumor_value_df[ 'Tumor Volume (mm3)']
fig1, ax1 = plt.subplots()
ax1.set_title('Tumor Volume (mm3) of Mice ater Treatment')
ax1.set_ylabel('Tumor Volume (mm3)')
ax1.boxplot(tumor_value)
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin
capomulin_df = combined_data_df[(combined_data_df['Mouse ID'] == "s185")]
tumor_vol = capomulin_df["Tumor Volume (mm3)"]
timepoint = capomulin_df["Timepoint"]
tumor_vstimepoint, = plt.plot(timepoint, tumor_vol, color="blue", label="Mouse: s185" )
plt.title("Tumor volume over Time for s185 Using Capomulin")
plt.xlabel("Time Point")
plt.ylabel("Tumor Volume (mm3)")

plt.show()

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen
all_capomulin_df = final_tumor_value_df[(final_tumor_value_df['Drug Regimen'] == "Capomulin")]
all_capomulin_df

tumor_vol = all_capomulin_df["Tumor Volume (mm3)"]
weight = all_capomulin_df["Weight (g)"]
plt.scatter(weight, tumor_vol)
plt.title("Tumor Volume vs Mouse Weight")
plt.xlabel("Mouse Weight (g)")
plt.ylabel("Tumor Volume (mm3)")
# Out:
# Text(0, 0.5, 'Tumor Volume (mm3)')

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen

all_capomulin_df = final_tumor_value_df[(final_tumor_value_df['Drug Regimen'] == "Capomulin")]
all_capomulin_df

tumor_vol = all_capomulin_df["Tumor Volume (mm3)"]
weight = all_capomulin_df["Weight (g)"]
plt.scatter(weight, tumor_vol)
plt.title("Tumor Volume vs Mouse Weight for the Capomulin Regimen")
plt.xlabel("Mouse Weight (g)")
plt.ylabel("Tumor Volume (mm3)")

(slope, intercept, rvalue, pvalue, stderr) = linregress(weight, tumor_vol)
regress_values = weight * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(weight,regress_values,"r-")
print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 0.7686134812139
